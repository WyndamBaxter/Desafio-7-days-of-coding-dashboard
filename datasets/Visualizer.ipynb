# %%
import pandas as pd

df_completo = pd.read_parquet('F:/Programação/Desafio-7-days-of-coding-dashboard/resultados/df_emprestimos_completo.parquet')

# %%
df_completo.head(2)
# Out:
#    id_emprestimo codigo_barras data_renovacao         data_emprestimo  \
# 0         709684       L095049           None 2010-01-04 07:44:10.721
# 1         709685       L167050           None 2010-01-04 07:44:10.750
#
#                   data_devolucao matricula_ou_siape tipo_vinculo_usuario  \
# 0  2010/01/05 16:26:12.662000000       2008023265.0   ALUNO DE GRADUAÇÃO
# 1  2010/01/12 07:34:13.934000000       2008023265.0   ALUNO DE GRADUAÇÃO
#
#    id_exemplar            colecao                      biblioteca  \
# 0        13259  Acervo Circulante  Biblioteca Central Zila Mamede
# 1        70865  Acervo Circulante  Biblioteca Central Zila Mamede
#
#   status_material  localizacao          classe_CDU
# 0         REGULAR          630  Ciências aplicadas
# 1         REGULAR          647  Ciências aplicadas

# %%
df_completo.data_emprestimo = pd.to_datetime(df_completo.data_emprestimo)
df_completo.head(2)
# Out:
#    id_emprestimo codigo_barras data_renovacao         data_emprestimo  \
# 0         709684       L095049           None 2010-01-04 07:44:10.721
# 1         709685       L167050           None 2010-01-04 07:44:10.750
#
#                   data_devolucao matricula_ou_siape tipo_vinculo_usuario  \
# 0  2010/01/05 16:26:12.662000000       2008023265.0   ALUNO DE GRADUAÇÃO
# 1  2010/01/12 07:34:13.934000000       2008023265.0   ALUNO DE GRADUAÇÃO
#
#    id_exemplar            colecao                      biblioteca  \
# 0        13259  Acervo Circulante  Biblioteca Central Zila Mamede
# 1        70865  Acervo Circulante  Biblioteca Central Zila Mamede
#
#   status_material  localizacao          classe_CDU
# 0         REGULAR          630  Ciências aplicadas
# 1         REGULAR          647  Ciências aplicadas

# %%
emprestimo_ano = pd.read_parquet('F:/Programação/Desafio-7-days-of-coding-dashboard/resultados/emprestimo_ano.parquet')
emprestimo_ano
# Out:
#      ano  quantidade
# 0   2010      161394
# 1   2011      196390
# 2   2012      221365
# 3   2013      234749
# 4   2014      219189
# 5   2015      213582
# 6   2016      215900
# 7   2017      218462
# 8   2018      194080
# 9   2019      171801
# 10  2020       25610
